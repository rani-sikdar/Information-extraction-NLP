# %%
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')

# %%
#tokenization
for token in doc:
    print(token.text)

# %%
#part-of-speech taging 
data = []
for token in doc:
    data.append([token.text,token.lemma_ ,token.pos_ ,token.tag_ ,token.dep_,
         token.shape_, token.is_alpha, token.is_stop])
    #text | lemma | pos | tag | dep | shape | alpha | stop 

pd.DataFrame(data)
# Out:
#               0          1      2     3         4      5      6      7
# 0      European   european    ADJ    JJ      amod  Xxxxx   True  False
# 1   authorities  authority   NOUN   NNS     nsubj   xxxx   True  False
# 2         fined       fine   VERB   VBD      ROOT   xxxx   True  False
# 3        Google     Google  PROPN   NNP      dobj  Xxxxx   True  False
# 4             a          a    DET    DT       det      x   True   True
# 5        record     record   NOUN    NN      dobj   xxxx   True  False
# 6             $          $    SYM     $  quantmod      $  False  False
# 7           5.1        5.1    NUM    CD  compound    d.d  False  False
# 8       billion    billion    NUM    CD    nummod   xxxx   True  False
# 9            on         on    ADP    IN      prep     xx   True   True
# 10    Wednesday  Wednesday  PROPN   NNP      pobj  Xxxxx   True  False
# 11          for        for    ADP    IN      prep    xxx   True   True
# 12      abusing      abuse   VERB   VBG     pcomp   xxxx   True  False
# 13          its     -PRON-   PRON  PRP$      poss    xxx   True   True
# 14        power      power   NOUN    NN      dobj   xxxx   True  False
# 15           in         in    ADP    IN      prep     xx   True   True
# 16          the        the    DET    DT       det    xxx   True   True
# 17       mobile     mobile    ADJ    JJ      amod   xxxx   True  False
# 18        phone      phone   NOUN    NN  compound   xxxx   True  False
# 19       market     market   NOUN    NN      pobj   xxxx   True  False
# 20          and        and  CCONJ    CC        cc    xxx   True   True
# 21      ordered      order   VERB   VBD      conj   xxxx   True  False
# 22          the        the    DET    DT       det    xxx   True   True
# 23      company    company   NOUN    NN      dobj   xxxx   True  False
# 24           to         to   PART    TO       aux     xx   True   True
# 25        alter      alter   VERB    VB     xcomp   xxxx   True  False
# 26          its     -PRON-   PRON  PRP$      poss    xxx   True   True
# 27    practices   practice   NOUN   NNS      dobj   xxxx   True  False

# %%
#Visualizing the dependency parse
displacy.serve(doc,style="dep")    #syntactic dependies
# Out:
# C:\Users\kratika\Anaconda3\lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="40d0a21be96f481699cc6779d5992490-0" class="displacy" width="4950" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">European</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">authorities</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">fined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">record</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">5.1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">billion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Wednesday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">abusing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">power</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">mobile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">phone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">market</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">ordered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">alter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">practices</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-40d0a21be96f481699cc6779d5992490-0-0" stroke-width="2px" d="M70,614.5 C70,527.0 195.0,527.0 195.0,614.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-40d0a21be96f481699cc6779d5992490-0-0" class="displacy-label" startOffset="50%"
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
#dependency parsing 
        #noun chunks - "based noun phrases -flat phrases that have a noun as their head"\
data_ = []
for chunk in doc.noun_chunks:
    data_.append([chunk.text,chunk.root.text, chunk.root.dep_,
         chunk.root.head.text])    # text | root text | root dep | root head text 

pd.DataFrame(data_)
# Out:
#                          0            1      2        3
# 0     European authorities  authorities  nsubj    fined
# 1                   Google       Google   dobj    fined
# 2                 a record       record   dobj    fined
# 3                Wednesday    Wednesday   pobj       on
# 4                its power        power   dobj  abusing
# 5  the mobile phone market       market   pobj       in
# 6              the company      company   dobj  ordered
# 7            its practices    practices   dobj    alter

# %%
#Navigating the parse tree

#head  #child  #dep
data__ =[]
for token in doc :
    data__.append([token.text,token.dep_,token.head.text,token.head.pos,
                  [child for child in token.children]])  #text | dep | head text | head pos | children

pd.DataFrame(data__)
# Out:
#               0         1            2    3  \
# 0      European      amod  authorities   92
# 1   authorities     nsubj        fined  100
# 2         fined      ROOT        fined  100
# 3        Google      dobj        fined  100
# 4             a       det       record   92
# 5        record      dobj        fined  100
# 6             $  quantmod      billion   93
# 7           5.1  compound      billion   93
# 8       billion    nummod       record   92
# 9            on      prep       record   92
# 10    Wednesday      pobj           on   85
# 11          for      prep        fined  100
# 12      abusing     pcomp          for   85
# 13          its      poss        power   92
# 14        power      dobj      abusing  100
# 15           in      prep      abusing  100
# 16          the       det       market   92
# 17       mobile      amod       market   92
# 18        phone  compound       market   92
# 19       market      pobj           in   85
# 20          and        cc        fined  100
# 21      ordered      conj        fined  100
# 22          the       det      company   92
# 23      company      dobj      ordered  100
# 24           to       aux        alter  100
# 25        alter     xcomp      ordered  100
# 26          its      poss    practices   92
# 27    practices      dobj        alter  100
#
#                                                    4
# 0                                                 []
# 1                                         [European]
# 2   [authorities, Google, record, for, and, ordered]
# 3                                                 []
# 4                                                 []
# 5                                   [a, billion, on]
# 6                                                 []
# 7                                                 []
# 8                                           [$, 5.1]
# 9                                        [Wednesday]
# 10                                                []
# 11                                         [abusing]
# 12                                       [power, in]
# 13                                                []
# 14                                             [its]
# 15                                          [market]
# 16                                                []
# 17                                                []
# 18                                                []
# 19                              [the, mobile, phone]
# 20                                                []
# 21                                  [company, alter]
# 22                                                []
# 23                                             [the]
# 24                                                []
# 25                                   [to, practices]
# 26                                                []
# 27                                             [its]

# %%
#Named entity recoginition 
_data_ =[]
for ent in doc.ents:
    _data_.append([ent.text,ent.start_char,ent.end_char,ent.label_])

pd.DataFrame(_data_)
# Out:
#                        0   1   2      3
# 0               European   0   8   NORP
# 1                 Google  27  33    ORG
# 2  a record $5.1 billion  34  55  MONEY
# 3              Wednesday  59  68   DATE

# %%
#visualizing named entity
pprint([(X.text, X.label_) for X in doc.ents])

displacy.render(doc,style='ent', jupyter=True)
# Out:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('a record $5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities fined
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     a record $5.1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for abusing its power in the mobile phone market and ordered the company to alter its practices</div>

# %%
#token
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'B', 'MONEY'),
#  (record, 'I', 'MONEY'),
#  ($, 'I', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', '')]

# %%
#extracting named entity from an article
from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 179

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 89,
#          'GPE': 16,
#          'ORG': 34,
#          'DATE': 31,
#          'FAC': 1,
#          'CARDINAL': 4,
#          'NORP': 2,
#          'ORDINAL': 1,
#          'PRODUCT': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Strzok', 31), ('F.B.I.', 17), ('Trump', 12)]

# %%
sentences = [x for x in article.sents]
print(sentences[21])
# Out:
# “A lengthy investigation and multiple rounds of congressional testimony failed to produce a shred of evidence that Special Agent Strzok’s personal views ever affected his work.

# %%
displacy.render(nlp(str(sentences[21])), jupyter=True, style='ent')
# Out:
# C:\Users\kratika\Anaconda3\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5; direction: ltr">“A lengthy investigation and multiple rounds of congressional testimony failed to produce a shred of evidence that Special Agent Strzok’s personal views ever affected his work.</div>

# %%
displacy.render(nlp(str(sentences[21])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="21d7b3a275464fa0a8f542a69936a665-0" class="displacy" width="3410" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">“</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">lengthy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">investigation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">multiple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">rounds</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">congressional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">testimony</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">failed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">produce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">shred</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">evidence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Special</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Agent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Strzok</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">personal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">views</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">ever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">affected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">work.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21d7b3a275464fa0a8f542a69936a665-0-0" stroke-width="2px" d="M70,482.0 C70,2.0 1250.0,2.0 1250.0,482.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-21d7b3a275464fa0a8f542a69936a665-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,484.0 L62,472.0 78,472.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-21d7b3a275464fa0a8f542a69936a665-0-1" stroke-width="2px" d="M190,482.0 C190,362.0 380

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[21])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('lengthy', 'ADJ', 'lengthy'),
#  ('investigation', 'NOUN', 'investigation'),
#  ('multiple', 'ADJ', 'multiple'),
#  ('rounds', 'NOUN', 'round'),
#  ('congressional', 'ADJ', 'congressional'),
#  ('testimony', 'NOUN', 'testimony'),
#  ('failed', 'VERB', 'fail'),
#  ('produce', 'VERB', 'produce'),
#  ('shred', 'NOUN', 'shred'),
#  ('evidence', 'NOUN', 'evidence'),
#  ('Special', 'PROPN', 'Special'),
#  ('Agent', 'PROPN', 'Agent'),
#  ('Strzok', 'PROPN', 'Strzok'),
#  ('personal', 'ADJ', 'personal'),
#  ('views', 'NOUN', 'view'),
#  ('affected', 'VERB', 'affect'),
#  ('work', 'NOUN', 'work')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[21])).ents])
# Out:
# {}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[21]])
# Out:
# [(“, 'O', ''), (A, 'O', ''), (lengthy, 'O', ''), (investigation, 'O', ''), (and, 'O', ''), (multiple, 'O', ''), (rounds, 'O', ''), (of, 'O', ''), (congressional, 'O', ''), (testimony, 'O', ''), (failed, 'O', ''), (to, 'O', ''), (produce, 'O', ''), (a, 'O', ''), (shred, 'O', ''), (of, 'O', ''), (evidence, 'O', ''), (that, 'O', ''), (Special, 'O', ''), (Agent, 'O', ''), (Strzok, 'O', ''), (’s, 'O', ''), (personal, 'O', ''), (views, 'O', ''), (ever, 'O', ''), (affected, 'O', ''), (his, 'O', ''), (work, 'O', ''), (., 'O', '')]

# %%
displacy.render(article,jupyter=True,style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">     F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Criticized Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Is Fired - The New York Times                                                                                 SectionsSEARCHSkip to contentSkip to site indexPoliticsLog
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     InLog InToday’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  PaperPolitics|F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Criticized Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Is FiredSubscribeLog InAdvertisementSupported byF.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Criticized Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Is FiredImagePeter
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a top
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  counterintelligence agent who was taken off the special counsel investigation after his disparaging texts about President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were uncovered, was fired.CreditCreditT.J.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kirkpatrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for The New York TimesBy
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Adam Goldman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Michael S. SchmidtAug
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 2018WASHINGTON —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
